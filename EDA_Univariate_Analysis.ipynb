# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
# Part 1.

# %%
    # 1.1. Frequency tables:

# %%
df = pd.read_csv('/Users/adamaskari/Downloads/amz_uk_price_prediction_dataset.csv')
df.head()
# Out:
#    uid        asin                                              title  stars  \
# 0    1  B09B96TG33  Echo Dot (5th generation, 2022 release) | Big ...    4.7
# 1    2  B01HTH3C8S  Anker Soundcore mini, Super-Portable Bluetooth...    4.7
# 2    3  B09B8YWXDF  Echo Dot (5th generation, 2022 release) | Big ...    4.7
# 3    4  B09B8T5VGV  Echo Dot with clock (5th generation, 2022 rele...    4.7
# 4    5  B09WX6QD65  Introducing Echo Pop | Full sound compact Wi-F...    4.6
#
#    reviews  price  isBestSeller  boughtInLastMonth        category
# 0    15308  21.99         False                  0  Hi-Fi Speakers
# 1    98099  23.99          True                  0  Hi-Fi Speakers
# 2    15308  21.99         False                  0  Hi-Fi Speakers
# 3     7205  31.99         False                  0  Hi-Fi Speakers
# 4     1881  17.99         False                  0  Hi-Fi Speakers

# %%
frequency_table = df['category'].value_counts()
frequency_table.head(5)
# Out:
# category
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
# Name: count, dtype: int64

# %%
    # 1.2. Visualisations:

# %%
top_categories = [
    'Sports & Outdoors',
    'Beauty',
    'Handmade Clothing, Shoes & Accessories',
    'Bath & Body',
    'Birthday Gifts'
]
filtered_df = df[df['category'].isin(top_categories)]

# %%
fig, axes=plt.subplots()
sns.barplot(x=frequency_table.index, y=frequency_table.values, palette="Set3", hue=frequency_table.index,legend=False
            , order=['Sports & Outdoors', 'Beauty', 'Handmade Clothing, Shoes & Accessories', 'Bath & Body', 'Birthday Gifts'], ax=axes)
axes.set_ylabel("Quantity")
axes.set_xlabel("Category")
plt.show()

# %%
filtered_df['category'].value_counts().plot.pie(autopct = '%.1f%%', startangle=90, color=sns.color_palette("Set3"));
plt.show()

# %%
# Part 2.

# %%
    # 2.1. Measures of Certainty:

# %%
mean_price = df['price'].mean()
median_price = df['price'].median()
mode_price = df['price'].mode() [0]

mean_price, median_price, mode_price
# Out:
# (np.float64(89.24380943923663), 19.09, np.float64(9.99))

# %%
# Mode is much lower than the average

# %%
sns.histplot(x=filtered_df['category'], y=filtered_df['price'], kde=True, bins=60, color="salmon", ax=axes);
plt.show()

# %%
sns.boxplot(x=filtered_df['category'], color="lightblue");
plt.show()

# %%
# Part 3.

# %%
    # 3.1. Measures of Centrality

# %%
mean_rating = df['stars'].mean()
median_rating = df['stars'].median()
mode_rating = df['stars'].mode() [0]

mean_rating, median_rating, mode_rating
# Out:
# (np.float64(2.152836472966065), 0.0, np.float64(0.0))

# %%
variance_rating = df['stars'].var()
std_dev_rating = df['stars'].std()
min_rating = df['stars'].min()
max_rating = df['stars'].max()
range_rating = max_price - min_price

variance_price, std_dev_price, min_price, max_price, range_price
# Out:
# (4.81743402976196, 2.1948653785054697, 0.0, 5.0, 5.0)

# %%
skewness_rating = df['stars'].skew()
skewness_rating
# Out:
# np.float64(0.08120735761080985)

# %%
sns.histplot(x=df['category'], y=df['stars'], kde=True, bins=60, color="salmon", ax=axes);
plt.show()
